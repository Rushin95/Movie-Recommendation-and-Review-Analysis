# %% [markdown]
# # MOVIE REVIEWS SENTIMENT ANALYSIS

# %%
#Python 3
import re #Please check that you have these!
from os import listdir
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Rushin
# [nltk_data]     Naik\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import numpy as np #Only end of recommendation system is affected

# %%
import matplotlib.pyplot as plt #Only plotting will not work

# %% [markdown]
# # Work with a single review

# %% [raw]
# Movie reviews are taken and adapted from "Large Movie Review Dataset v1.0":
# http://ai.stanford.edu/~amaas/data/sentiment/
#
# Folders structure:
# Practical_NLP
# |-neg                     #Folder contains all negative reviews
#    |-0_3_tt0064354.txt    #File name format: [revID]_[score]_[movID].txt
#    |-1_1_tt0100680.txt
#    |-
# |-pos                     #Folder contains all positive revies
#    |-0_9_tt0453418.txt
#    |-1_7_tt0453418.txt
#    |-...
# |-polarity_words.csv      #File format: word,polarity
#
# |-Recommendation.ipynb
# |-Recommendation.py
# |-Sentiment_analysis.ipynb
# |-Sentiment_analysis.py

# %%
#Open and output each line of a review
file1 = 'positive_reviews/6_10_tt0100680.txt'
f = open(file1,'r')
for line in f:
    print(line)
# Out:
# Fair drama/love story movie that focuses on the lives of blue collar people finding new life thru new love.The acting here is good but the film fails in cinematography,screenplay,directing and editing.The story/script is only average at best.This film will be enjoyed by Fonda and De Niro fans and by people who love middle age love stories where in the coartship is on a more wiser and cautious level.It would also be interesting for people who are interested on the subject matter regarding illiteracy.......

# %%
f = open(file1,'r')
words = [] #List of all words in a review
for line in f:
    line = line.strip()
    words = line.split() #Split by spaces
    
print(sorted(words)) #remained "word." or "word:", etc.
# Out:
# ['De', 'Fair', 'Fonda', 'Niro', 'a', 'acting', 'age', 'also', 'and', 'and', 'and', 'and', 'are', 'at', 'average', 'be', 'be', 'best.This', 'blue', 'but', 'by', 'by', 'cautious', 'cinematography,screenplay,directing', 'coartship', 'collar', 'drama/love', 'editing.The', 'enjoyed', 'fails', 'fans', 'film', 'film', 'finding', 'focuses', 'for', 'good', 'here', 'illiteracy.......', 'in', 'in', 'interested', 'interesting', 'is', 'is', 'is', 'level.It', 'life', 'lives', 'love', 'love', 'love.The', 'matter', 'middle', 'more', 'movie', 'new', 'new', 'of', 'on', 'on', 'on', 'only', 'people', 'people', 'people', 'regarding', 'stories', 'story', 'story/script', 'subject', 'that', 'the', 'the', 'the', 'the', 'thru', 'where', 'who', 'who', 'will', 'wiser', 'would']

# %%
f = open(file1,'r')
words = []
for line in f:
    line = line.strip()
    words = re.split(' |, |: |!|\.|"|\'|\(|\)|\?|/|;|>|<',line) 
    #Split review using all possible punctuations as delimiters
    # "|" is used to show where each delimiter ends

print(sorted(words)) #Same words, inneficient, better a dictionary with a word and its count
# Out:
# ['', '', '', '', '', '', '', 'De', 'Fair', 'Fonda', 'It', 'Niro', 'The', 'The', 'This', 'a', 'acting', 'age', 'also', 'and', 'and', 'and', 'and', 'are', 'at', 'average', 'be', 'be', 'best', 'blue', 'but', 'by', 'by', 'cautious', 'cinematography,screenplay,directing', 'coartship', 'collar', 'drama', 'editing', 'enjoyed', 'fails', 'fans', 'film', 'film', 'finding', 'focuses', 'for', 'good', 'here', 'illiteracy', 'in', 'in', 'interested', 'interesting', 'is', 'is', 'is', 'level', 'life', 'lives', 'love', 'love', 'love', 'love', 'matter', 'middle', 'more', 'movie', 'new', 'new', 'of', 'on', 'on', 'on', 'only', 'people', 'people', 'people', 'regarding', 'script', 'stories', 'story', 'story', 'subject', 'that', 'the', 'the', 'the', 'the', 'thru', 'where', 'who', 'who', 'will', 'wiser', 'would']

# %%
f = open(file1,'r')
vocab = {} #Dictionary: {word1:count1, word2:count2,...}
for line in f:
    line = line.strip().lower()
    words = re.split(' |, |: |!|\.|"|\'|\(|\)|\?|/|;|>|<',line)
    for word in words:
        if word == '': #No need to have empty strings in the vocabulary
            continue
        vocab[word]=vocab.get(word,0)+1 #Increment the count of the just seen word

print(sorted(vocab))
vLen = len(vocab) #Length of vocabulary
print("The vocabulary contains ",vLen," words.")
# Out:
# ['a', 'acting', 'age', 'also', 'and', 'are', 'at', 'average', 'be', 'best', 'blue', 'but', 'by', 'cautious', 'cinematography,screenplay,directing', 'coartship', 'collar', 'de', 'drama', 'editing', 'enjoyed', 'fails', 'fair', 'fans', 'film', 'finding', 'focuses', 'fonda', 'for', 'good', 'here', 'illiteracy', 'in', 'interested', 'interesting', 'is', 'it', 'level', 'life', 'lives', 'love', 'matter', 'middle', 'more', 'movie', 'new', 'niro', 'of', 'on', 'only', 'people', 'regarding', 'script', 'stories', 'story', 'subject', 'that', 'the', 'this', 'thru', 'where', 'who', 'will', 'wiser', 'would']
# The vocabulary contains  65  words.

# %%
#The above procedure can be used done with NLTK module
from nltk.tokenize import word_tokenize #Load NLTK word_tokenize module
#If you got an error - just watch the explanation of the next cell
#Resume the work after the next cell

# %%
f = open(file1,'r')
vocab = {}
for line in f:
    line = line.strip().lower()
    words = word_tokenize(line.strip().lower()) #Instead of regular expressions use this to tokenize
    for word in words:
        if word == '':
            continue
        vocab[word]=vocab.get(word,0)+1

print(sorted(vocab))
vLen = len(vocab)
print("The vocabulary contains ",vLen," words.") 
#Vocabulary length is different as word_tokenize also included ",",".","...", 
#but did not tokenize "story/script", "best.this"
# Out:
# [',', '.', '...', 'a', 'acting', 'age', 'also', 'and', 'are', 'at', 'average', 'be', 'best.this', 'blue', 'but', 'by', 'cautious', 'cinematography', 'coartship', 'collar', 'de', 'directing', 'drama/love', 'editing.the', 'enjoyed', 'fails', 'fair', 'fans', 'film', 'finding', 'focuses', 'fonda', 'for', 'good', 'here', 'illiteracy', 'in', 'interested', 'interesting', 'is', 'level.it', 'life', 'lives', 'love', 'love.the', 'matter', 'middle', 'more', 'movie', 'new', 'niro', 'of', 'on', 'only', 'people', 'regarding', 'screenplay', 'stories', 'story', 'story/script', 'subject', 'that', 'the', 'thru', 'where', 'who', 'will', 'wiser', 'would']
# The vocabulary contains  69  words.

# %%
plt.bar(range(len(vocab)), vocab.values()) #Show counts for each word in our dictionary
plt.show() #Most counts are 1

# %%
top20_vocab = dict(sorted(vocab.items(), key=lambda x: -x[1])[:20]) #Dictionary of the words with the highest count
top20_vocab
# Out:
# {',': 2,
#  '...': 2,
#  'and': 4,
#  'be': 2,
#  'by': 2,
#  'drama/love': 1,
#  'fair': 1,
#  'film': 2,
#  'focuses': 1,
#  'in': 2,
#  'is': 3,
#  'love': 2,
#  'movie': 1,
#  'new': 2,
#  'on': 3,
#  'people': 3,
#  'story': 1,
#  'that': 1,
#  'the': 4,
#  'who': 2}

# %%
#Bar chart of 20 words with the highest count
plt.bar(range(len(top20_vocab)), top20_vocab.values(), align='center')
plt.xlim([-1,20])
plt.xticks(range(len(top20_vocab)), top20_vocab.keys(), rotation=45)
plt.show() #Most polarized words (important for classification) as "good" appear only 1 time

# %%
# Load polarity words, adapted from http://sentiwordnet.isti.cnr.it/
f = open('polarity_words_uniq.csv','r')
i = 0
pol_words = {} #Dictionary of polarity words: {pol_word1:polarity1, pol_word2:polarity2,...}
next(f) #Skip header
for line in f:
    line = line.strip()
    line = line.split(',')
    pol_words[line[0]] = np.sign(float(line[1])) #+1 is for positive words, -1 is for negative words
pol_words
# Out:
# {'thin-skinned': -1.0,
#  'shrieking': 1.0,
#  'dustiness': -1.0,
#  'frangibleness': -1.0,
#  'guesswork': -1.0,
#  'penetratively': 1.0,
#  'cristobal_balenciaga': 1.0,
#  'cuspidal': 1.0,
#  'accretionary': -1.0,
#  'auxiliary_storage': -1.0,
#  'fray': -1.0,
#  'private_foundation': -1.0,
#  'hypoglycemic': -1.0,
#  'mirrorlike': 1.0,
#  'permission': 1.0,
#  'gaseous': -1.0,
#  'foggy': -1.0,
#  'goddamn': -1.0,
#  'obsessiveness': 1.0,
#  'acarpous': -1.0,
#  'heartbreaking': -1.0,
#  'meticulous': 1.0,
#  'etiolate': -1.0,
#  'haemulidae': 1.0,
#  'deficiency': -1.0,
#  'derivative': -1.0,
#  'upheaval': -1.0,
#  'chelonethida': -1.0,
#  'eye_opener': -1.0,
#  'peronosporaceae': 1.0,
#  'magniloquent': 1.0,
#  'mousey': -1.0,
#  'nefarious': -1.0,
#  'dracunculidae': 1.0,
#  'native_beech': -1.0,
#  'liquidity': 1.0,
#  'whoreson': -1.0,
#  'saboteur': -1.0,
#  'niche': 1.0,
#  'awestricken': 1.0,
#  'candescent': 1.0,
#  'mahuang': 1.0,
#  'redeem': -1.0,
#  'armored': -1.0,
#  'star_grass': 1.0,
#  'obduracy': -1.0,
#  'crack': -1.0,
#  'rascally': -1.0,
#  'surprise': -1.0,
#  'feverous': -1.0,
#  'get_around': -1.0,
#  'livistona_australis': 1.0,
#  'soybean': 1.0,
#  'genus_liriope': -1.0,
#  'expressway': 1.0,
#  'paternalistic': 1.0,
#  'stonewaller': -1.0,
#  'tongue_twister': -1.0,
#  'common_good': 1.0,
#  'extend_oneself': -1.0,
#  'salvific': 1.0,
#  'nemertina': 1.0,
#  'craps': 1.0,
#  'livable': 1.0,
#  'dirndl': -1.0,
#  'scalar': 1.0,
#  'pancreatitis': -1.0,
#  'mesne_lord': 1.0,
#  'pseudobulb': -1.0,
#  'actual_sin': 1.0,
#  'motortruck': 1.0,
#  'able-bodiedism': 1.0,
#  'familiar': 1.0,
#  'borderline_intelligence': 1.0,
#  'accordance_of_rights': 1.0,
#  'bereft': -1.0,
#  'overt': -1.0,
#  'pretentiousness': 1.0,
#  'lung-power': 1.0,
#  'interfering': -1.0,
#  'three-lobed': 1.0,
#  'gustatory_modality': 1.0,
#  'scoffer': -1.0,
#  'lymphopathia_venereum': -1.0,
#  'waste': -1.0,
#  'plexus_mesentericus': -1.0,
#  'mischievousness': -1.0,
#  'wise': 1.0,
#  'identity_matrix': -1.0,
#  'noumenon': 1.0,
#  'nephroptosis': -1.0,
#  'heath_hen': -1.0,
#  'polyuria': -1.0,
#  'khukuri': 1.0,
#  'perked_up': 1.0,
#  'savior': -1.0,
#  'ungainly': -1.0,
#  'albinotic': -1.0,
#  'kip': -1.0,
#  'unsated': -1.0,
#  'duck_soup': 1.0,
#  'hirudo': -1.0,
#  'malignant': 1.0,
#  'contumaciously': 1.0,
#  'hypothermia': -1.0,
#  'sweetheart': 1.0,
#  'hermitic': 1.0,
#  'podlike': -1.0,
#  'oppressiveness': -1.0,
#  'nonviolent': -1.0,
#  'pipe_down': -1.0,
#  'swayback': -1.0,
#  'asynchronous': -1.0,
#  'bungarus': -1.0,
#  'mellowly': 1.0,
#  'suppuration': -1.0,
#  'gift_wrapping': 1.0,
#  'misfortunate': -1.0,
#  'ganesa': 1.0,
#  'embedded': 1.0,
#  'matt': -1.0,
#  'buckthorn_berry': -1.0,
#  'motiveless': -1.0,
#  'nebo': 1.0,
#  'premature_baby': -1.0,
#  'hurt': -1.0,
#  'spoken': -1.0,
#  'organically': 1.0,
#  'bombproof': 1.0,
#  'fourth_crusade': -1.0,
#  'bracing': 1.0,
#  'precocial': 1.0,
#  'arteriosclerotic': -1.0,
#  'american_revised_version': 1.0,
#  'jitteriness': -1.0,
#  'palmy': 1.0,
#  'mule_skinner': -1.0,
#  'callous': -1.0,
#  'unrestrained': -1.0,
#  'profligate': -1.0,
#  'civic_spirit': 1.0,
#  'dissociative': -1.0,
#  'minaret': 1.0,
#  'disposition': 1.0,
#  'surd': -1.0,
#  'unstylish': -1.0,
#  'heatedly': 1.0,
#  'noncomprehensive': -1.0,
#  'catkinate': 1.0,
#  'obliteration': 1.0,
#  'falling': -1.0,
#  'unfeasible': -1.0,
#  'cestoda': 1.0,
#  'gorgeous': 1.0,
#  'unelaborate': 1.0,
#  'unresponsiveness': -1.0,
#  'digressive': 1.0,
#  'louvered': -1.0,
#  'straining': -1.0,
#  'underhanded': -1.0,
#  'discriminating': 1.0,
#  'knockoff': -1.0,
#  'square-toed': 1.0,
#  'chronic_obstructive_pulmonary_disease': -1.0,
#  'devilish': -1.0,
#  'cornel': 1.0,
#  'predisposition': 1.0,
#  'mockingly': 1.0,
#  'fugitive': 1.0,
#  'smack': 1.0,
#  'ravenous': -1.0,
#  'lashings': -1.0,
#  'get_on': 1.0,
#  'hard-boiled': -1.0,
#  'jingoist': 1.0,
#  'breach_of_contract': 1.0,
#  'solemn': 1.0,
#  'prochlorperazine': -1.0,
#  'round-eyed': 1.0,
#  'tachinidae': -1.0,
#  'phlegm': 1.0,
#  'all_important': 1.0,
#  'agnail': -1.0,
#  'vestigial': -1.0,
#  'colourless': -1.0,
#  'alacrity': 1.0,
#  'complexity': 1.0,
#  'superannuate': -1.0,
#  'lysis': 1.0,
#  'credit': 1.0,
#  'hedged': -1.0,
#  'good-natured': 1.0,
#  'ponderous': 1.0,
#  'exhaustion': 1.0,
#  'obtrusively': 1.0,
#  'excitedly': 1.0,
#  'fulsomely': 1.0,
#  'gruffly': 1.0,
#  'wilkins_micawber': -1.0,
#  'rustbelt': -1.0,
#  'ipsedixitism': -1.0,
#  'temptation': 1.0,
#  'horse_trader': -1.0,
#  'malta_fever': -1.0,
#  'noxiously': -1.0,
#  'atomic_number_3': -1.0,
#  'accommodative': 1.0,
#  'elves': 1.0,
#  'illimitable': -1.0,
#  'enduring': -1.0,
#  'precision': -1.0,
#  'tet': 1.0,
#  'tsatske': -1.0,
#  'liturgist': -1.0,
#  'encephalitis': -1.0,
#  'hawk_moth': 1.0,
#  'bang_up': -1.0,
#  'bratty': -1.0,
#  'unstrained': 1.0,
#  'bless': -1.0,
#  'folk_etymology': -1.0,
#  'technophile': 1.0,
#  'hydrocharitaceae': 1.0,
#  'unimpassioned': 1.0,
#  'semiconducting': 1.0,
#  'anxiety_reaction': 1.0,
#  'in_store': 1.0,
#  'daydream': -1.0,
#  'stumbling_block': 1.0,
#  'phantasm': -1.0,
#  'orange_pekoe': 1.0,
#  'venus': 1.0,
#  'nonmandatory': -1.0,
#  'odium': -1.0,
#  'stealth_fighter': 1.0,
#  'dispirited': -1.0,
#  'pyelitis': -1.0,
#  'break_up': -1.0,
#  'kabbalist': 1.0,
#  'jade': 1.0,
#  'clear_and_present_danger': -1.0,
#  'oxyopia': 1.0,
#  'custodial': 1.0,
#  'obloquy': -1.0,
#  'egg-and-dart': 1.0,
#  'authoritarianism': -1.0,
#  'no_matter': -1.0,
#  'worthful': 1.0,
#  "earth's_crust": -1.0,
#  'million': -1.0,
#  'almsgiving': -1.0,
#  'laxation': -1.0,
#  'spironolactone': -1.0,
#  'western_saddle': 1.0,
#  'acrobatic_stunt': -1.0,
#  'shuttlecock_fern': 1.0,
#  'isobutylphenyl_propionic_acid': -1.0,
#  'happily': 1.0,
#  'reliableness': 1.0,
#  'unpermissiveness': -1.0,
#  'heaps': -1.0,
#  'miserably': 1.0,
#  'world-beater': 1.0,
#  'callosectomy': -1.0,
#  'caption': 1.0,
#  'captivated': -1.0,
#  'of_sound_mind': 1.0,
#  'clapperclaw': -1.0,
#  'clock_dial': 1.0,
#  'spot': -1.0,
#  'stinker': -1.0,
#  'soup': -1.0,
#  'plebiscite': 1.0,
#  'flop': -1.0,
#  'efficaciousness': 1.0,
#  'scowling': -1.0,
#  'undutiful': -1.0,
#  'munificently': 1.0,
#  'covering_fire': -1.0,
#  'necrobiosis': -1.0,
#  'overstated': 1.0,
#  'adulterous': -1.0,
#  'atonalism': -1.0,
#  'reaction': 1.0,
#  'critique': 1.0,
#  'dyspepsia': -1.0,
#  'hathaway': -1.0,
#  'article_of_faith': -1.0,
#  'odd-pinnate': 1.0,
#  'feral_man': -1.0,
#  'indecently': -1.0,
#  'brainish': -1.0,
#  'mind-boggling': 1.0,
#  'bewilderingly': 1.0,
#  'delayed_allergy': 1.0,
#  'futureless': -1.0,
#  'irish_bull': -1.0,
#  'downhill': -1.0,
#  'purification': 1.0,
#  'purifying': 1.0,
#  'imperial': 1.0,
#  'sibilation': -1.0,
#  'mechanistically': 1.0,
#  'goof-proof': -1.0,
#  'mullet': 1.0,
#  'cornpone': -1.0,
#  'solace': -1.0,
#  'nympholepsy': -1.0,
#  'picaninny': -1.0,
#  'fogbound': -1.0,
#  'pursued': -1.0,
#  'brummell': 1.0,
#  'unmined': -1.0,
#  'unfertilized': -1.0,
#  'absorbed': 1.0,
#  'bare-breasted': 1.0,
#  'evocation': 1.0,
#  'tomato_blight': 1.0,
#  'suck': -1.0,
#  'scrubland': -1.0,
#  'jarrell': 1.0,
#  'guileful': 1.0,
#  'sandaled': -1.0,
#  'sissiness': -1.0,
#  'pettish': -1.0,
#  'idolised': 1.0,
#  'public_nudity': -1.0,
#  'macula': -1.0,
#  'humin': -1.0,
#  'acephaly': -1.0,
#  'improperness': -1.0,
#  'endometritis': -1.0,
#  'pocket_flask': 1.0,
#  'castle_in_the_air': -1.0,
#  'wee_small_voice': 1.0,
#  'choriomeningitis': -1.0,
#  'materialization': 1.0,
#  'toboggan_cap': 1.0,
#  'tactlessness': -1.0,
#  'crookedly': 1.0,
#  'costoaxillary_vein': -1.0,
#  'stone-deaf': -1.0,
#  'commode': 1.0,
#  'juglans': -1.0,
#  'follow-through': 1.0,
#  'cliched': -1.0,
#  'disgustingness': -1.0,
#  'contradistinguish': 1.0,
#  'dancing_lady_orchid': -1.0,
#  'ethos': 1.0,
#  'rusty': 1.0,
#  'defiance': 1.0,
#  'unquenchable': -1.0,
#  "huntington's_chorea": 1.0,
#  'grounds': -1.0,
#  'startled': -1.0,
#  'unmindful': -1.0,
#  'action_replay': 1.0,
#  'washed-out': -1.0,
#  'chatterer': -1.0,
#  'maianthemum': -1.0,
#  'dissimulation': -1.0,
#  'pleasurably': 1.0,
#  'gall': -1.0,
#  'katharometer': -1.0,
#  'amendable': 1.0,
#  'copious': 1.0,
#  'sitta': -1.0,
#  'order_pseudoscorpionida': -1.0,
#  'shivery': -1.0,
#  'orb-weaving': -1.0,
#  'after_a_fashion': -1.0,
#  'natural_theology': 1.0,
#  'welcoming': -1.0,
#  'hamelia': 1.0,
#  'wangler': -1.0,
#  'hugger_mugger': 1.0,
#  'crudely': 1.0,
#  'shirtsleeves': -1.0,
#  'already': 1.0,
#  'power-assisted': -1.0,
#  'uncontested': -1.0,
#  'eight-day': -1.0,
#  'disability': -1.0,
#  'genus_ipomoea': -1.0,
#  'undefined': -1.0,
#  'loth': -1.0,
#  'capitalistic': 1.0,
#  'saccharum_munja': -1.0,
#  'elbowing': -1.0,
#  'big_brother': 1.0,
#  'unclear': 1.0,
#  'rapaciously': 1.0,
#  'amok': -1.0,
#  'right-eyed': 1.0,
#  'dysostosis_multiplex': -1.0,
#  'inodorous': -1.0,
#  'at_the_ready': 1.0,
#  'untrusting': -1.0,
#  "treasurer's_check": -1.0,
#  'runtiness': 1.0,
#  'strengthening': 1.0,
#  'unavenged': -1.0,
#  'woolly_mullein': -1.0,
#  'liquifiable': 1.0,
#  'saturation': -1.0,
#  'facility': 1.0,
#  'tiresomeness': -1.0,
#  'preciously': -1.0,
#  'synergetic': 1.0,
#  'truehearted': 1.0,
#  'undoubtedly': 1.0,
#  'sight-sing': -1.0,
#  'plausibleness': 1.0,
#  'empathic': 1.0,
#  'turnoff': -1.0,
#  'commercially': 1.0,
#  'fibbing': 1.0,
#  'ornament': -1.0,
#  'syncretistic': 1.0,
#  'forlorn_hope': -1.0,
#  'injury': -1.0,
#  'wide-eyed': 1.0,
#  'possession': 1.0,
#  'dodging': 1.0,
#  'impermissibility': -1.0,
#  'significance': 1.0,
#  'sordidness': -1.0,
#  'hypovitaminosis': -1.0,
#  'melursus_ursinus': -1.0,
#  'camlan': -1.0,
#  'conditioned_stimulus': 1.0,
#  'unapologetic': -1.0,
#  'concuss': -1.0,
#  'fibrous': -1.0,
#  'crabapple': -1.0,
#  'untutored': 1.0,
#  'dysomia': -1.0,
#  'disdainfulness': -1.0,
#  'impartially': 1.0,
#  'out_of_true': -1.0,
#  'addiction': 1.0,
#  'noise': -1.0,
#  'cross_infection': 1.0,
#  'transversally': 1.0,
#  'philhellenic': 1.0,
#  'gimp': -1.0,
#  'wood_file': 1.0,
#  'hardfisted': -1.0,
#  'wariness': 1.0,
#  'lathery': -1.0,
#  'length_of_service': 1.0,
#  'evanesce': -1.0,
#  'blow': -1.0,
#  'rave-up': -1.0,
#  'godlessness': -1.0,
#  'kindness': 1.0,
#  'cattiness': -1.0,
#  'incense_wood': 1.0,
#  'electromotive': 1.0,
#  'plaquenil': -1.0,
#  'fight_back': 1.0,
#  'bear_upon': 1.0,
#  'tautly': 1.0,
#  'infelicitous': -1.0,
#  'ignominious': -1.0,
#  'line-shooter': 1.0,
#  'reverse': -1.0,
#  'micro': -1.0,
#  'genus_oestrus': -1.0,
#  'ambulate': -1.0,
#  "mason's_level": 1.0,
#  'pertinent': 1.0,
#  'raptorial_bird': -1.0,
#  'leptospirosis': -1.0,
#  'blitheness': 1.0,
#  'punch-up': -1.0,
#  'leprosy': -1.0,
#  'murmurous': -1.0,
#  'pig-headedly': -1.0,
#  'exhaustively': 1.0,
#  'referable': -1.0,
#  'withered': 1.0,
#  'artistic_production': 1.0,
#  'bare-ass': 1.0,
#  'hard-line': 1.0,
#  'restful': 1.0,
#  'sporting_lady': -1.0,
#  'sciolism': 1.0,
#  'osteophyte': -1.0,
#  'phylloclad': 1.0,
#  'inexorability': -1.0,
#  'desirability': 1.0,
#  'polarisation': 1.0,
#  'steaminess': -1.0,
#  'at_odds': 1.0,
#  'chicane': -1.0,
#  'brown': -1.0,
#  'glossy': 1.0,
#  'crossness': -1.0,
#  'leatherjacket': -1.0,
#  'put_to_death': 1.0,
#  'eye-popping': 1.0,
#  'dreamfully': 1.0,
#  'toothless': -1.0,
#  'alcalescent': -1.0,
#  'abstinence': 1.0,
#  'variola_major': 1.0,
#  'missed': -1.0,
#  'suasible': -1.0,
#  'friendliness': -1.0,
#  'enthrallment': 1.0,
#  'tread': -1.0,
#  'labyrinthodontia': 1.0,
#  'normative': 1.0,
#  'similitude': -1.0,
#  'sporophyll': 1.0,
#  'amiably': 1.0,
#  'stylishly': 1.0,
#  'ineptly': 1.0,
#  'swelter': -1.0,
#  'marvel': 1.0,
#  'nonlethal': -1.0,
#  'leptospira': -1.0,
#  'springless': -1.0,
#  'insensately': 1.0,
#  'garbed': -1.0,
#  "crohn's_disease": -1.0,
#  'cushy': -1.0,
#  'dash': -1.0,
#  'cretinous': -1.0,
#  'choiceness': 1.0,
#  'galvanisation': 1.0,
#  'lightsome': 1.0,
#  'heedlessly': -1.0,
#  'territorial': 1.0,
#  'sympathize': 1.0,
#  'fit': 1.0,
#  'chrome': -1.0,
#  'crystallized': 1.0,
#  'aetiologist': 1.0,
#  'forficula_auricularia': -1.0,
#  'eligible': 1.0,
#  'fill_the_bill': 1.0,
#  'outrageousness': -1.0,
#  'flippancy': -1.0,
#  'pyrogenic': -1.0,
#  'astounding': 1.0,
#  'bounderish': -1.0,
#  'isoagglutinogen': -1.0,
#  'gammy': -1.0,
#  'arthropathy': 1.0,
#  'undulatory': 1.0,
#  'period': 1.0,
#  'degraded': -1.0,
#  'dermacentor': 1.0,
#  'well-adjusted': 1.0,
#  'lookout': 1.0,
#  'calm_down': -1.0,
#  'killer_bee': 1.0,
#  'joyride': -1.0,
#  'lacking': -1.0,
#  'communicate': -1.0,
#  'fulfill': 1.0,
#  'oxyphenbutazone': -1.0,
#  'quibble': -1.0,
#  'arrant': 1.0,
#  'whit_leather': -1.0,
#  'impression': -1.0,
#  'restricted': -1.0,
#  'epileptic': -1.0,
#  'unapproachable': -1.0,
#  'hock': -1.0,
#  'unsatisfiable': -1.0,
#  'stridence': 1.0,
#  'hoodmould': 1.0,
#  'eradication': 1.0,
#  'balk': -1.0,
#  'isoniazid': -1.0,
#  'gradual': -1.0,
#  'preciseness': 1.0,
#  'pappataci_fever': -1.0,
#  'trichrome': 1.0,
#  'high_status': 1.0,
#  'soigne': 1.0,
#  'by_artificial_means': -1.0,
#  'virion': 1.0,
#  'dazed': -1.0,
#  'methodically': 1.0,
#  'arthur_symons': 1.0,
#  'waxlike': 1.0,
#  'macho': 1.0,
#  'nitid': 1.0,
#  'unintelligibility': 1.0,
#  'greenwood': 1.0,
#  'obsessive-compulsive': 1.0,
#  'satanophobia': -1.0,
#  'noncrucial': -1.0,
#  'actionable': 1.0,
#  'dogging': -1.0,
#  'cheval_glass': 1.0,
#  'unvendible': -1.0,
#  'counteractively': 1.0,
#  'ruddy': 1.0,
#  'stated': 1.0,
#  'inflame': -1.0,
#  'sunny': 1.0,
#  'unpretentiousness': -1.0,
#  'soft_option': -1.0,
#  'formidable': 1.0,
#  'load-bearing': 1.0,
#  'find': 1.0,
#  'venose': 1.0,
#  'predicament': -1.0,
#  'communistic': -1.0,
#  'officious': -1.0,
#  'penetrative': 1.0,
#  'wet': -1.0,
#  'conniving': 1.0,
#  'reparation': -1.0,
#  'baroness': 1.0,
#  'underbred': -1.0,
#  'aplanatic': 1.0,
#  'underwing': 1.0,
#  'seminude': 1.0,
#  'mirthfully': 1.0,
#  'sexed': 1.0,
#  'present_times': 1.0,
#  'lactose_intolerance': -1.0,
#  'waterproofing': 1.0,
#  'systematically': 1.0,
#  'smelly': -1.0,
#  'burnability': 1.0,
#  'lymphuria': -1.0,
#  'petiolule': 1.0,
#  'loggerhead': -1.0,
#  'apotheosis': 1.0,
#  'ungeared': -1.0,
#  'overprotection': -1.0,
#  'subject': -1.0,
#  'lecherous': -1.0,
#  'banana_peel': -1.0,
#  'willing_and_able': -1.0,
#  'jersey': 1.0,
#  'exquisite': 1.0,
#  'ulterior': -1.0,
#  'albinic': -1.0,
#  'acute-angled_triangle': 1.0,
#  'lowly': -1.0,
#  'anthrax': -1.0,
#  'reanimated': 1.0,
#  'co-star': 1.0,
#  'formalised': -1.0,
#  'wantonly': 1.0,
#  'topping': 1.0,
#  'peliosis': -1.0,
#  'nonresinous': -1.0,
#  'insatiate': -1.0,
#  'mental_hospital': -1.0,
#  'etiquette': 1.0,
#  'hands-off': -1.0,
#  'wondering': 1.0,
#  'sanguine': 1.0,
#  'noticeably': 1.0,
#  'smidge': 1.0,
#  'piassava_palm': -1.0,
#  'inhuman': -1.0,
#  'knock_against': -1.0,
#  'obstreperous': -1.0,
#  'novillada': 1.0,
#  'crystal_clear': 1.0,
#  'sugarless': -1.0,
#  'bladderlike': 1.0,
#  'puff_up': -1.0,
#  'favourably': 1.0,
#  'dimness': -1.0,
#  'sinusoidally': 1.0,
#  'artificially': -1.0,
#  'episcleritis': -1.0,
#  'faraway': 1.0,
#  'foolhardy': -1.0,
#  'immoderate': -1.0,
#  'chaffer': 1.0,
#  'exonerative': 1.0,
#  'blameable': -1.0,
#  'wise_guy': -1.0,
#  'aesthetic': 1.0,
#  'transfer_rna': -1.0,
#  'summum_bonum': 1.0,
#  'animate_being': -1.0,
#  'nimble': 1.0,
#  'victimized': 1.0,
#  'exchange': -1.0,
#  'indomitable': -1.0,
#  'ruck': -1.0,
#  'inculpable': 1.0,
#  'famed': 1.0,
#  'mission_impossible': -1.0,
#  'dissociable': 1.0,
#  'instigator': -1.0,
#  'unladylike': 1.0,
#  'chopped': 1.0,
#  'sopranino': 1.0,
#  'mind-blowing': 1.0,
#  'atrocious': -1.0,
#  'orientation': 1.0,
#  'shrove_tuesday': 1.0,
#  'geyser': -1.0,
#  'chalcid': -1.0,
#  'flammable': -1.0,
#  'unassertively': 1.0,
#  'perpendicular_style': -1.0,
#  'biform': 1.0,
#  'arhat': 1.0,
#  'unsensational': -1.0,
#  "waste_one's_time": -1.0,
#  'rhymeless': -1.0,
#  'limen': 1.0,
#  'balmy': 1.0,
#  'injun': -1.0,
#  'kind-hearted': 1.0,
#  'smooch': 1.0,
#  'cling': 1.0,
#  'hormone_replacement_therapy': 1.0,
#  'presumption': -1.0,
#  'conoid': 1.0,
#  'sexual_desire': 1.0,
#  'presymptomatic': -1.0,
#  'uselessly': 1.0,
#  'glucophage': -1.0,
#  'external_storage': -1.0,
#  'strictly': 1.0,
#  'harmonic': 1.0,
#  'transposable': 1.0,
#  'sustainable': 1.0,
#  'palatableness': 1.0,
#  'retrogressive': -1.0,
#  'megalomaniac': -1.0,
#  'medical_aid': -1.0,
#  'flood': -1.0,
#  'kindheartedness': 1.0,
#  'uneventful': -1.0,
#  'unhinged': -1.0,
#  'wax_paper': -1.0,
#  'bodhisattva': 1.0,
#  'estival': 1.0,
#  'pinafore': -1.0,
#  'assiduousness': 1.0,
#  'common_sorrel': -1.0,
#  'snorty': -1.0,
#  'antifeminism': 1.0,
#  'obnoxious': -1.0,
#  'providence': 1.0,
#  'disfiguration': -1.0,
#  'tayassu': -1.0,
#  'impenitence': -1.0,
#  'spoiled': -1.0,
#  'pressed': 1.0,
#  'engraulis_encrasicholus': -1.0,
#  'synesthetic': -1.0,
#  'co-beneficiary': -1.0,
#  'grated_cheese': -1.0,
#  'angel': 1.0,
#  'comical': 1.0,
#  'sense_of_right_and_wrong': 1.0,
#  'wroth': -1.0,
#  'ungusseted': -1.0,
#  'goa_powder': -1.0,
#  'mournful': -1.0,
#  'pinch': -1.0,
#  'decoupage': 1.0,
#  'gulp': -1.0,
#  'pitch': 1.0,
#  'ruminative': 1.0,
#  'eunuch': -1.0,
#  'vernal': 1.0,
#  'tinderbox': -1.0,
#  'wildfowl': 1.0,
#  'disoblige': -1.0,
#  'dreg': -1.0,
#  'stifling': -1.0,
#  'doctor_of_public_health': 1.0,
#  'benign_tumor': -1.0,
#  'shirring': -1.0,
#  'natty': 1.0,
#  'photographic': 1.0,
#  'fatherhood': 1.0,
#  'globose': 1.0,
#  'radical': 1.0,
#  'flaccidity': 1.0,
#  'laconic': 1.0,
#  'clutter': -1.0,
#  'fructify': 1.0,
#  'new-mown': 1.0,
#  'crispate': -1.0,
#  'saveloy': 1.0,
#  'psocopterous_insect': -1.0,
#  'covalence': 1.0,
#  'oceanic': -1.0,
#  'altercate': 1.0,
#  'lateness': 1.0,
#  'get_well': 1.0,
#  'likeable': 1.0,
#  'casuistical': -1.0,
#  'fulgurating': 1.0,
#  'whole_milk': 1.0,
#  'idyll': 1.0,
#  'drink_down': 1.0,
#  'broken_heart': 1.0,
#  'tolerance': 1.0,
#  'spatulate': 1.0,
#  'hand_to_hand': 1.0,
#  'plenarily': 1.0,
#  'sick_person': -1.0,
#  'genus_babesia': -1.0,
#  'goggles': -1.0,
#  'deflationary': 1.0,
#  'entrust': 1.0,
#  'shaktism': -1.0,
#  'numinous': 1.0,
#  'sheep_tick': 1.0,
#  'lyrate_leaf': -1.0,
#  'devastation': -1.0,
#  'know_the_score': 1.0,
#  'pearlweed': -1.0,
#  'eumenes': -1.0,
#  'duckbill': -1.0,
#  'unasterisked': -1.0,
#  'disputative': 1.0,
#  'cognac': 1.0,
#  'anecdotic': 1.0,
#  'concussion': -1.0,
#  'baboo': 1.0,
#  'fruitfulness': 1.0,
#  'menial': -1.0,
#  'sweetish': 1.0,
#  'hospitableness': 1.0,
#  'half-slip': -1.0,
#  'high-sounding': 1.0,
#  'seriocomic': 1.0,
#  'glorification': 1.0,
#  'genus_sitta': -1.0,
#  'sheep-tick': 1.0,
#  'uncooperative': -1.0,
#  'arise': -1.0,
#  'uninventive': -1.0,
#  'pluralist': -1.0,
#  'gloatingly': 1.0,
#  'thrombosed': -1.0,
#  'ascendable': 1.0,
#  'mammut': -1.0,
#  'sourpuss': -1.0,
#  'baron': 1.0,
#  'separateness': 1.0,
#  'groundbreaking': 1.0,
#  'deprecative': -1.0,
#  'snot-nosed': -1.0,
#  'garcinia_cambogia': -1.0,
#  'conditionally': -1.0,
#  'upbound': 1.0,
#  'absently': 1.0,
#  'affirmative': 1.0,
#  'foothill': -1.0,
#  'cut_short': 1.0,
#  'belonging': 1.0,
#  'blood_spavin': -1.0,
#  'rofecoxib': -1.0,
#  'rhapis_excelsa': 1.0,
#  'minor_suit': -1.0,
#  'conundrum': -1.0,
#  'cheer': 1.0,
#  'fitter': 1.0,
#  'fish_species': 1.0,
#  'worldly-wise': 1.0,
#  'every_week': -1.0,
#  'readably': 1.0,
#  'confidently': 1.0,
#  'ireful': -1.0,
#  'relative': -1.0,
#  'okay': 1.0,
#  'unenergetically': 1.0,
#  'unredeemed': -1.0,
#  'humanist': 1.0,
#  'hemimetamorphic': -1.0,
#  'caryophyllales': 1.0,
#  'pastness': -1.0,
#  'duodenal_ulcer': -1.0,
#  'uncommunicative': -1.0,
#  'conservatory': 1.0,
#  'cleat': 1.0,
#  'backseat_driver': 1.0,
#  'dope': 1.0,
#  'take_heart': 1.0,
#  'fair_weather': 1.0,
#  'seed_grain': 1.0,
#  'letdown': -1.0,
#  'blabber': -1.0,
#  'homily': 1.0,
#  'caveat_emptor': -1.0,
#  'tainted': -1.0,
#  'eurythmy': 1.0,
#  'virginal': 1.0,
#  'termes': -1.0,
#  'hereditarianism': 1.0,
#  'growl': -1.0,
#  'provident': 1.0,
#  'unthinkingly': 1.0,
#  'detoxify': 1.0,
#  'mortified': -1.0,
#  'unmannered': -1.0,
#  'draw_in': 1.0,
#  'kingship': 1.0,
#  'abysmally': -1.0,
#  'headline': 1.0,
#  'denominator': 1.0,
#  'ldl_cholesterol': -1.0,
#  'approximation': 1.0,
#  'monocytic_leukaemia': -1.0,
#  'amour_propre': -1.0,
#  'stigmatic': -1.0,
#  'mountain_ash': -1.0,
#  'toxic_condition': -1.0,
#  'bartholomeu_dias': 1.0,
#  'genuinely': 1.0,
#  'struggle': -1.0,
#  'sharing': 1.0,
#  'single': -1.0,
#  'long-suffering': -1.0,
#  'tearaway': -1.0,
#  'ultraconservative': -1.0,
#  'slanderer': 1.0,
#  'funnel': 1.0,
#  'cromorne': -1.0,
#  'debauched': -1.0,
#  'busboy': -1.0,
#  'teaching': 1.0,
#  'blackbody': 1.0,
#  'depraved': -1.0,
#  'ungenerous': 1.0,
#  'humility': -1.0,
#  'genus_anser': -1.0,
#  'informative': 1.0,
#  'atopognosia': -1.0,
#  'tiger-striped': 1.0,
#  'conversant': 1.0,
#  'balding': -1.0,
#  'uncrowded': -1.0,
#  'lacerate': -1.0,
#  'congenital_pancytopenia': 1.0,
#  'aortitis': -1.0,
#  'ignorance': 1.0,
#  'natural_shape': -1.0,
#  'unperceiving': -1.0,
#  'contriteness': -1.0,
#  'piss-up': -1.0,
#  'bank-depositor_relation': 1.0,
#  'larghetto': 1.0,
#  'family_tachinidae': -1.0,
#  'cashmere': 1.0,
#  'high-spiritedness': 1.0,
#  'prate': -1.0,
#  'genus_echinococcus': 1.0,
#  'bedizen': -1.0,
#  'noisiness': 1.0,
#  'effluvium': -1.0,
#  'workfellow': -1.0,
#  'mocking': -1.0,
#  'vd': 1.0,
#  'sportingly': 1.0,
#  'maintenance': 1.0,
#  'top-quality': 1.0,
#  'unchristianly': -1.0,
#  'fatuity': 1.0,
#  'fraudulence': -1.0,
#  'up_on': 1.0,
#  'genus_brachychiton': -1.0,
#  'lust_after': 1.0,
#  'get_a_whiff': 1.0,
#  'uncongenial': -1.0,
#  'blissfully': 1.0,
#  'civilized': 1.0,
#  'altered': -1.0,
#  'growth-onset_diabetes': -1.0,
#  'mephistophelian': -1.0,
#  'aphyllanthaceae': -1.0,
#  'sabbatarian': -1.0,
#  'unknowable': -1.0,
#  'knockout_punch': -1.0,
#  'begrimed': -1.0,
#  'intelligible': 1.0,
#  'anthonomus_grandis': -1.0,
#  'agglomerate': 1.0,
#  'organ_stop': 1.0,
#  'maraschino': 1.0,
#  'chemical_element': -1.0,
#  'order_cydippidea': 1.0,
#  'seditious': 1.0,
#  'gallantly': 1.0,
#  'verification': 1.0,
#  'fondler': 1.0,
#  ...}

# %%
pol_words.get('and',None),pol_words.get('love',None),pol_words.get('interesting',None) #Check polarity of several words
# Out:
# (None, 1.0, 1.0)

# %%
words = top20_vocab.keys() #List of top20 words
counts = top20_vocab.values() #their counts
pos = range(len(top20_vocab)) #their positions on a bar chart
barWords= plt.bar(pos, counts, align='center', color='w') #make bar chart of counts for all top20 words
for i,word in enumerate(words):
    polarity = pol_words.get(word,None) #Get polarity of each word
    if polarity==1:
        barWords[i].set_color('r') #Change the color to "red" for positive word
    if polarity==-1:
        barWords[i].set_color('b') #Change the color to "blue" for negative word
plt.xlim([-1,20]) #Set the range to display
plt.xticks(pos, words, rotation=90) #Add words to the ticks on X axis
plt.show() #Most polarized words (important for classification) as "good" appear only 1 time

# %%
# Naive Bayes model:
# Type of review is defined by:
# the number of positive words - number of negative words
# If there are more positive words --> positive review
# otherwise --> negative review
vote = 0
for word in vocab.keys():
    polarity = pol_words.get(word,0)
    vote += polarity
if vote>0:
    print("Positive review, vote =",vote)
elif vote == 0:
    print("Neutral review") #If the number of positive words == number of negative words
else:
    print("Negative review, vote =",vote)
# Out:
# Positive review, vote = 3.0

# %%
# The above analysis is combined in this cell.
# For a single review
file1 = 'positive_reviews/6_10_tt0100680.txt' #Check other 
f = open(file1,'r')

vocab = {}
for line in f:
    line = line.strip().lower()
    words = re.split(' |, |: |!|\.|"|\(|\)|\?|/|;|>|<',line)
    for word in words:
        if word == '':
            continue
        vocab[word]=vocab.get(word,0)+1

vLen = len(vocab)
top20_vocab = dict(sorted(vocab.items(), key=lambda x: -x[1])[:20])

counts = top20_vocab.values()
words = top20_vocab.keys()
pos = range(len(top20_vocab))
barWords= plt.bar(pos, counts, align='center', color='w')
for i,word in enumerate(words):
    polarity = pol_words.get(word,None)
    if polarity==1:
        barWords[i].set_color('r') #Change the color of only the i-th bar
    if polarity==-1:
        barWords[i].set_color('b')
plt.xlim([-1,20])
plt.xticks(pos, words, rotation=90)
plt.show() #Most polarized words (important for classification) as "good" appear only 1 time

vote = 0
for word in vocab.keys():
    polarity = pol_words.get(word,0)
    vote += polarity
if vote>0:
    print("Positive review, vote =",vote)
elif vote == 0:
    print("Neutral review")
else:
    print("Negative review, vote =",vote)
# Out:
# Positive review, vote = 5.0

# %%
#For a single review with NLTK
file1 = 'positive_reviews/6_10_tt0100680.txt'
f = open(file1,'r')

vocab = {}

for line in f:
    line = line.strip().lower()
    words = word_tokenize(line.strip().lower())
    for word in words:
        if word == '':
            continue
        vocab[word]=vocab.get(word,0)+1

vLen = len(vocab)
top20_vocab = dict(sorted(vocab.items(), key=lambda x: -x[1])[:20])

counts = top20_vocab.values()
words = top20_vocab.keys()
pos = range(len(top20_vocab))
barWords= plt.bar(pos, counts, align='center', color='w')
for i,word in enumerate(words):
    polarity = pol_words.get(word,None)
    if polarity==1:
        barWords[i].set_color('r') #Change the color of only the i-th bar
    if polarity==-1:
        barWords[i].set_color('b')
plt.xlim([-1,20])
plt.xticks(pos, words, rotation=90)
plt.show() #Most polarized words (important for classification) as "good" appear only 1 time

vote = 0
for word in vocab.keys():
    polarity = pol_words.get(word,0)
    vote += polarity
if vote>0:
    print("Positive review, vote =",vote)
elif vote == 0:
    print("Neutral review")
else:
    print("Negative review, vote =",vote)
# Out:
# Positive review, vote = 3.0

# %% [markdown]
# # Classify all reviews

# %%
# Using regular expressions for tokenization
fold = 'positive_reviews/'
n_pos = 0 #Number of positive reviews
n_files = 0 #Total number of files
for file in listdir(fold): #Get the name of each file in fold
    n_files += 1
    if n_files>5: #Comment this
        break     #Comment this
    file1 = fold + file
    vote = 0 #The total vote for each review
    try:
        f = open(file1,'r')
        for line in f:
            print(line) #Comment this
            line = line.strip().lower()
            words = re.split(' |, |: |!|\.|"|\'|\(|\)|\?|/|;|>|<',line)
            for word in words:
                polarity = pol_words.get(word,0)
                vote += polarity
        print('\n') #Comment this
        if vote>0:
            print("Positive review, vote =",vote) #Comment this
            n_pos += 1
        elif vote == 0:
            print("Neutral review") #Comment this
            pass
        else:
            print("Negative review, vote =",vote) #Comment this
            pass
        print('\n') #Comment this
    except:
        continue

#Check the 4th review with the vote -14. It is indeed difficult to say from the text that this is a positive review.
print("Classifier accuracy is",n_pos/n_files)
# Out:
# Bromwell High is a cartoon comedy. It ran at the same time as some other programs about school life, such as "Teachers". My 35 years in the teaching profession lead me to believe that Bromwell High's satire is much closer to reality than is "Teachers". The scramble to survive financially, the insightful students who can see right through their pathetic teachers' pomp, the pettiness of the whole situation, all remind me of the schools I knew and their students. When I saw the episode in which a student repeatedly tried to burn down the school, I immediately recalled ......... at .......... High. A classic line: INSPECTOR: I'm here to sack one of your teachers. STUDENT: Welcome to Bromwell High. I expect that many adults of my age think that Bromwell High is far fetched. What a pity that it isn't!
#
#
# Positive review, vote = 11.0
#
#
# Homelessness (or Houselessness as George Carlin stated) has been an issue for years but never a plan to help those on the street that were once considered human who did everything from going to school, work, or vote for the matter. Most people think of the homeless as just a lost cause while worrying about things such as racism, the war on Iraq, pressuring kids to succeed, technology, the elections, inflation, or worrying if they'll be next to end up on the streets.<br /><br />But what if you were given a bet to live on the streets for a month without the luxuries you once had from a home, the entertainment sets, a bathroom, pictures on the wall, a computer, and everything you once treasure to see what it's like to be homeless? That is Goddard Bolt's lesson.<br /><br />Mel Brooks (who directs) who stars as Bolt plays a rich man who has everything in the world until deciding to make a bet with a sissy rival (Jeffery Tambor) to see if he can live in the streets for thirty days without the luxuries; if Bolt succeeds, he can do what he wants with a future project of making more buildings. The bet's on where Bolt is thrown on the street with a bracelet on his leg to monitor his every move where he can't step off the sidewalk. He's given the nickname Pepto by a vagrant after it's written on his forehead where Bolt meets other characters including a woman by the name of Molly (Lesley Ann Warren) an ex-dancer who got divorce before losing her home, and her pals Sailor (Howard Morris) and Fumes (Teddy Wilson) who are already used to the streets. They're survivors. Bolt isn't. He's not used to reaching mutual agreements like he once did when being rich where it's fight or flight, kill or be killed.<br /><br />While the love connection between Molly and Bolt wasn't necessary to plot, I found "Life Stinks" to be one of Mel Brooks' observant films where prior to being a comedy, it shows a tender side compared to his slapstick work such as Blazing Saddles, Young Frankenstein, or Spaceballs for the matter, to show what it's like having something valuable before losing it the next day or on the other hand making a stupid bet like all rich people do when they don't know what to do with their money. Maybe they should give it to the homeless instead of using it like Monopoly money.<br /><br />Or maybe this film will inspire you to help others.
#
#
# Positive review, vote = 29.0
#
#
# Brilliant over-acting by Lesley Ann Warren. Best dramatic hobo lady I have ever seen, and love scenes in clothes warehouse are second to none. The corn on face is a classic, as good as anything in Blazing Saddles. The take on lawyers is also superb. After being accused of being a turncoat, selling out his boss, and being dishonest the lawyer of Pepto Bolt shrugs indifferently "I'm a lawyer" he says. Three funny words. Jeffrey Tambor, a favorite from the later Larry Sanders show, is fantastic here too as a mad millionaire who wants to crush the ghetto. His character is more malevolent than usual. The hospital scene, and the scene where the homeless invade a demolition site, are all-time classics. Look for the legs scene and the two big diggers fighting (one bleeds). This movie gets better each time I see it (which is quite often).
#
#
# Positive review, vote = 1.0
#
#
# This is easily the most underrated film inn the Brooks cannon. Sure, its flawed. It does not give a realistic view of homelessness (unlike, say, how Citizen Kane gave a realistic view of lounge singers, or Titanic gave a realistic view of Italians YOU IDIOTS). Many of the jokes fall flat. But still, this film is very lovable in a way many comedies are not, and to pull that off in a story about some of the most traditionally reviled members of society is truly impressive. Its not The Fisher King, but its not crap, either. My only complaint is that Brooks should have cast someone else in the lead (I love Mel as a Director and Writer, not so much as a lead).
#
#
# Negative review, vote = -15.0
#
#
# This is not the typical Mel Brooks film. It was much less slapstick than most of his movies and actually had a plot that was followable. Leslie Ann Warren made the movie, she is such a fantastic, under-rated actress. There were some moments that could have been fleshed out a bit more, and some scenes that could probably have been cut to make the room to do so, but all in all, this is worth the price to rent and see it. The acting was good overall, Brooks himself did a good job without his characteristic speaking to directly to the audience. Again, Warren was the best actor in the movie, but "Fume" and "Sailor" both played their parts well.
#
#
# Positive review, vote = 11.0
#
#
# Classifier accuracy is 0.6666666666666666
